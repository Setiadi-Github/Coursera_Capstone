# %% [markdown]
# ## Project Capstone: Battle of Neighbourhoods - Week 1_Part1
# #### 1. Introduction/Business Problem
# Toronto is the capital city of the Canadian province of Ontario. With a recorded population of 2,731,571 in 2016, It is the most populous city in Canada and the fourth most populous city in North America. The city is the anchor of the Golden Horseshoe, an urban agglomeration of 9,245,438 people (as of 2016) surrounding the western end of Lake Ontario, while the Greater Toronto Area (GTA) proper had a 2016 population of 6,417,516. Toronto is an international centre of business, finance, arts, and culture, and is recognized as one of the most multicultural and cosmopolitan cities in the world the diverse population of Toronto reflects its current and historical role as an important destination for immigrants to Canada. More than 50 percent of residents belong to a visible minority population group, and over 200 distinct ethnic origins are represented among its inhabitants. While the majority of Torontonians speak English as their primary language, over 160 languages are spoken in the city
#
# #### 2. Business Problems
# At Toronto there no information relate Neighbourhoods is there any a hotel/restaurant near this area within 1000 M. what kind of most top ten "Common Venues" popular entertainment on those area as a venues categories such as: Fast food Restaurant, Bar, coffe shop, etc.
#
# #### 3. Expected / Interested Audience
# By giving the solution of information from the above business problems such as explore the maps & display list the most top ten "Common Venues" around those area.
# #### 4. Data Collection
# To complete this case, we require data set as follows:
#
# Part_1:
# - Venue data relate to Hotel & Restaurant. This will help us find the neighborhoods that are more suitable to find the best hotel & Restaurant
# Part_2:
# - List of neighborhoods in Toronto, Ontario Canada
# - Latitute and Longiture of these neigborhoods
#
# #### 5. Extracting The Data
# Scrapping of Toronto neighborhoods via Wikipedia
# Getting Latitute and Longitude data of these neighborhoods via Geocoder packages

# %% [markdown]
# #### Part 1 - Import Library

# %%
# Import libraries
import numpy as np # data in a vectorized manner manipulation
import pandas as pd # data analsysis
import requests # HTTP library
from bs4 import BeautifulSoup # scraping library

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe
import json # JSON files manipulation

from sklearn.cluster import KMeans # clustering algorithm

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt

#!conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim

#!conda install -c conda-forge folium=0.5.0 --yes
import folium # map rendering library

print("@@Libraries Imported@@")
# Out:
# @@Libraries Imported@@

# %% [markdown]
# ####  foursquare credential id

# %%
CLIENT_ID = 'Y4AOTAYDY23ILH3DR4XZZDYEZDHNECVYXORDA4N4WWLLJ3NB' # your Foursquare ID
CLIENT_SECRET = 'XSI4HLFPMXC1PFUWGYR1U35DVKVOO32KWR3FQGGIJINNPEG2' # your Foursquare Secret
VERSION = '20200804' # Foursquare API version
LIMIT = 100

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: Y4AOTAYDY23ILH3DR4XZZDYEZDHNECVYXORDA4N4WWLLJ3NB
# CLIENT_SECRET:XSI4HLFPMXC1PFUWGYR1U35DVKVOO32KWR3FQGGIJINNPEG2

# %% [markdown]
# #### Credentials and Location
# Use geopy library to get the latitude and longitude values of Toronto

# %%
address = 'Toronto, Ontario'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Toronto are 43.6534817, -79.3839347.

# %% [markdown]
# ####  Search for hotel & restaurant within 1000 Meter

# %%
#Quering for hotel & restaurant

qry_htl = 'hotel'
qry_rst = 'restaurant'

radius = 1000
url_hotel = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, qry_htl, radius, LIMIT)
url_restaurant = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, qry_rst, radius, LIMIT)
#url

# %% [markdown]
# #### Send the GET Request of hotel & restaurants and examine the results

# %%
results_hotel = requests.get(url_hotel).json()
results_restaurant = requests.get(url_restaurant).json()
results_restaurant
# Out:
# {'meta': {'code': 200, 'requestId': '5f31251970412b0a532df117'},
#  'response': {'venues': [{'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'primary': True,
#       'shortName': 'American'}],
#     'hasPerk': False,
#     'id': '4ad4c05ff964a52048f720e3',
#     'location': {'address': '110 Chestnut Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 224,
#      'formattedAddress': ['110 Chestnut Street',
#       'Toronto ON M5G 1R3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65488413420439,
#        'lng': -79.38593077371578}],
#      'lat': 43.65488413420439,
#      'lng': -79.38593077371578,
#      'postalCode': 'M5G 1R3',
#      'state': 'ON'},
#     'name': 'Hemispheres Restaurant & Bistro',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4ad4c05cf964a52006f620e3',
#     'location': {'address': '37 King Street East',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Le Meridien King Edward Hotel',
#      'distance': 763,
#      'formattedAddress': ['37 King Street East (at Le Meridien King Edward Hotel)',
#       'Toronto ON M5C 1E9',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64929834396347,
#        'lng': -79.37643067251867}],
#      'lat': 43.64929834396347,
#      'lng': -79.37643067251867,
#      'postalCode': 'M5C 1E9',
#      'state': 'ON'},
#     'name': "Victoria's Restaurant",
#     'referralId': 'v-1597056531',
#     'venuePage': {'id': '498556908'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'primary': True,
#       'shortName': 'American'}],
#     'hasPerk': False,
#     'id': '4ada5d5bf964a520e92121e3',
#     'location': {'address': '35 Church St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Front St E',
#      'distance': 973,
#      'formattedAddress': ['35 Church St (at Front St E)',
#       'Toronto ON M5E 1T3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64882370529773,
#        'lng': -79.37370210886002}],
#      'lat': 43.64882370529773,
#      'lng': -79.37370210886002,
#      'postalCode': 'M5E 1T3',
#      'state': 'ON'},
#     'name': 'The Hot House Restaurant & Bar',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '52af3b773cf9994f4e043c03',
#       'name': 'Szechuan Restaurant',
#       'pluralName': 'Szechuan Restaurants',
#       'primary': True,
#       'shortName': 'Szechuan'}],
#     'hasPerk': False,
#     'id': '5750b013498e755287c6de97',
#     'location': {'address': '988 Baldwin Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 839,
#      'formattedAddress': ['988 Baldwin Street', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655874,
#        'lng': -79.393826}],
#      'lat': 43.655874,
#      'lng': -79.393826,
#      'state': 'ON'},
#     'name': 'Some Time BBQ Grill Restaurant 碳烤屋',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d143941735',
#       'name': 'Breakfast Spot',
#       'pluralName': 'Breakfast Spots',
#       'primary': True,
#       'shortName': 'Breakfast'}],
#     'hasPerk': False,
#     'id': '4bd47e6fcfa7b7139f2924da',
#     'location': {'address': '389 Church St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Carlton St.',
#      'distance': 966,
#      'formattedAddress': ['389 Church St. (at Carlton St.)',
#       'Toronto ON M5B',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.661500159065305,
#        'lng': -79.3793192447337}],
#      'lat': 43.661500159065305,
#      'lng': -79.3793192447337,
#      'postalCode': 'M5B',
#      'state': 'ON'},
#     'name': 'Studio Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4b223f5af964a520ba4424e3',
#     'location': {'address': '225 Front St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'in InterContinental Toronto Centre',
#      'distance': 976,
#      'formattedAddress': ['225 Front St W (in InterContinental Toronto Centre)',
#       'Toronto ON M5V 2X3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.644749195919346,
#        'lng': -79.38511295085902}],
#      'lat': 43.644749195919346,
#      'lng': -79.38511295085902,
#      'neighborhood': 'Entertainment District',
#      'postalCode': 'M5V 2X3',
#      'state': 'ON'},
#     'name': 'Azure Restaurant & Bar',
#     'referralId': 'v-1597056531',
#     'venuePage': {'id': '136175835'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4d06c1ccc2e53704428cc567',
#     'location': {'address': '476 Dundas St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Huron',
#      'distance': 1026,
#      'formattedAddress': ['476 Dundas St. (Huron)', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6531846832903,
#        'lng': -79.3966766276528}],
#      'lat': 43.6531846832903,
#      'lng': -79.3966766276528,
#      'state': 'ON'},
#     'name': 'North-East Chinese Restaurant 華北美食',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d116941735',
#       'name': 'Bar',
#       'pluralName': 'Bars',
#       'primary': True,
#       'shortName': 'Bar'}],
#     'hasPerk': False,
#     'id': '4ad4c05df964a5203ff620e3',
#     'location': {'address': '30 Mercer Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at John St',
#      'distance': 1048,
#      'formattedAddress': ['30 Mercer Street (at John St)',
#       'Toronto ON M5V 1H3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64563436248102,
#        'lng': -79.39112538566908}],
#      'lat': 43.64563436248102,
#      'lng': -79.39112538566908,
#      'postalCode': 'M5V 1H3',
#      'state': 'ON'},
#     'name': 'Victor Restaurant & Bar',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d149941735',
#       'name': 'Thai Restaurant',
#       'pluralName': 'Thai Restaurants',
#       'primary': True,
#       'shortName': 'Thai'}],
#     'hasPerk': False,
#     'id': '4ad4c05ff964a52018f720e3',
#     'location': {'address': '338 Jarvis St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'north of Carlton Street',
#      'distance': 1179,
#      'formattedAddress': ['338 Jarvis St. (north of Carlton Street)',
#       'Toronto ON M4Y 2G6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66277006654972,
#        'lng': -79.37689434011018}],
#      'lat': 43.66277006654972,
#      'lng': -79.37689434011018,
#      'postalCode': 'M4Y 2G6',
#      'state': 'ON'},
#     'name': 'Cottage Restaurant & Lounge',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '4aef8854f964a5201cd921e3',
#     'location': {'address': '287 King St. W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at John St.',
#      'distance': 906,
#      'formattedAddress': ['287 King St. W (at John St.)',
#       'Toronto ON M5V 1J5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.646462521503445,
#        'lng': -79.38964414801342}],
#      'lat': 43.646462521503445,
#      'lng': -79.38964414801342,
#      'postalCode': 'M5V 1J5',
#      'state': 'ON'},
#     'name': 'Aroma Fine Indian Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '5a7c3e079de23b294a2c4117',
#     'location': {'address': '325 Bay St (31st floor)',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 512,
#      'formattedAddress': ['325 Bay St (31st floor)',
#       'Toronto ON M5H',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.649563,
#        'lng': -79.38059}],
#      'lat': 43.649563,
#      'lng': -79.38059,
#      'postalCode': 'M5H',
#      'state': 'ON'},
#     'name': 'Restaurant | Adelaide',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d123941735',
#       'name': 'Wine Bar',
#       'pluralName': 'Wine Bars',
#       'primary': True,
#       'shortName': 'Wine Bar'}],
#     'hasPerk': False,
#     'id': '4ad4c05cf964a520dff520e3',
#     'location': {'address': '301 Front St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': '301 Front St. W',
#      'distance': 1243,
#      'formattedAddress': ['301 Front St W (301 Front St. W)',
#       'Toronto ON M5V 2T6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.642537317144566,
#        'lng': -79.38704201569328}],
#      'lat': 43.642537317144566,
#      'lng': -79.38704201569328,
#      'postalCode': 'M5V 2T6',
#      'state': 'ON'},
#     'name': '360 Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '50ca02c0245f2d4aa8c2b313',
#     'location': {'address': '145 Richmond Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Hilton Toronto',
#      'distance': 398,
#      'formattedAddress': ['145 Richmond Street West (Hilton Toronto)',
#       'Toronto ON M5H 2L2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.650068857878594,
#        'lng': -79.38540891817722}],
#      'lat': 43.650068857878594,
#      'lng': -79.38540891817722,
#      'postalCode': 'M5H 2L2',
#      'state': 'ON'},
#     'name': 'Tundra Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'primary': True,
#       'shortName': 'New American'}],
#     'hasPerk': False,
#     'id': '4cffc78a75d3236a3b10e7f7',
#     'location': {'address': '130 Queen St W',
#      'cc': 'CA',
#      'country': 'Canada',
#      'crossStreet': 'University Ave',
#      'distance': 189,
#      'formattedAddress': ['130 Queen St W (University Ave)',
#       'M5H 2N6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651978959035155,
#        'lng': -79.3850485857013}],
#      'lat': 43.651978959035155,
#      'lng': -79.3850485857013,
#      'postalCode': 'M5H 2N6'},
#     'name': 'Osgoode Hall Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'primary': True,
#       'shortName': 'Caribbean'}],
#     'hasPerk': False,
#     'id': '53ae6660498e1ac3c1282743',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 279,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654727935791016,
#        'lng': -79.38092803955078}],
#      'lat': 43.654727935791016,
#      'lng': -79.38092803955078},
#     'name': 'Castries Bar & Five Way Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14a941735',
#       'name': 'Vietnamese Restaurant',
#       'pluralName': 'Vietnamese Restaurants',
#       'primary': True,
#       'shortName': 'Vietnamese'}],
#     'hasPerk': False,
#     'id': '4c476d6719fde21e32410876',
#     'location': {'address': '179 Dundas St. W.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Chestnut',
#      'distance': 264,
#      'formattedAddress': ['179 Dundas St. W. (at Chestnut)',
#       'Toronto ON M5G',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65506808,
#        'lng': -79.386375}],
#      'lat': 43.65506808,
#      'lng': -79.386375,
#      'postalCode': 'M5G',
#      'state': 'ON'},
#     'name': 'Cali Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '5b7618541ffe97002c1a13ae',
#     'location': {'address': '67 Richmond St West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 284,
#      'formattedAddress': ['67 Richmond St West',
#       'Toronto ON M5H 1W2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6513954168839,
#        'lng': -79.38188786532692}],
#      'lat': 43.6513954168839,
#      'lng': -79.38188786532692,
#      'postalCode': 'M5H 1W2',
#      'state': 'ON'},
#     'name': 'Maezo Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '56aa371be4b08b9a8d573538',
#       'name': 'Theme Restaurant',
#       'pluralName': 'Theme Restaurants',
#       'primary': True,
#       'shortName': 'Theme Restaurant'}],
#     'hasPerk': False,
#     'id': '56dd9d68498eb4e5edcb30f9',
#     'location': {'address': '40 Dundas St W Box 36,',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 294,
#      'formattedAddress': ['40 Dundas St W Box 36,',
#       'Toronto ON M5G 2C2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65610515821675,
#        'lng': -79.38349485397339}],
#      'lat': 43.65610515821675,
#      'lng': -79.38349485397339,
#      'postalCode': 'M5G 2C2',
#      'state': 'ON'},
#     'name': 'Spring Rolls | Japanese Restaurant in Toronto',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d14e941735',
#       'name': 'American Restaurant',
#       'pluralName': 'American Restaurants',
#       'primary': True,
#       'shortName': 'American'}],
#     'hasPerk': False,
#     'id': '4edbccaaf9abeea3db5268df',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 352,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65610066909799,
#        'lng': -79.38148016065777}],
#      'lat': 43.65610066909799,
#      'lng': -79.38148016065777},
#     'name': 'Terrace Restaurant at Elmwood',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '5834c90e110d032f3217f899',
#     'location': {'address': '67 Richmond Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Richmond and Bay Street',
#      'distance': 315,
#      'formattedAddress': ['67 Richmond Street West (Richmond and Bay Street)',
#       'Toronto ON M5H 1Z5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651090520885205,
#        'lng': -79.38184261322021}],
#      'lat': 43.651090520885205,
#      'lng': -79.38184261322021,
#      'postalCode': 'M5H 1Z5',
#      'state': 'ON'},
#     'name': 'Maezo Restaurant & Bar',
#     'referralId': 'v-1597056531',
#     'venuePage': {'id': '369067217'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4b295e10f964a520ba9d24e3',
#     'location': {'address': '14 Queen St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 313,
#      'formattedAddress': ['14 Queen St W', 'Toronto ON M5H 3X4', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652614361741726,
#        'lng': -79.38023131683906}],
#      'lat': 43.652614361741726,
#      'lng': -79.38023131683906,
#      'postalCode': 'M5H 3X4',
#      'state': 'ON'},
#     'name': 'Richtree Natural Market Restaurants',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'primary': True,
#       'shortName': 'Italian'}],
#     'hasPerk': False,
#     'id': '4ae9ef82f964a520cbb721e3',
#     'location': {'address': '108 Dundas St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Bay St.',
#      'distance': 242,
#      'formattedAddress': ['108 Dundas St W (at Bay St.)',
#       'Toronto ON M5G 1C3',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65565507065502,
#        'lng': -79.3841236014983}],
#      'lat': 43.65565507065502,
#      'lng': -79.3841236014983,
#      'postalCode': 'M5G 1C3',
#      'state': 'ON'},
#     'name': 'Alio Restaurant & Wine Bar',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1d2941735',
#       'name': 'Sushi Restaurant',
#       'pluralName': 'Sushi Restaurants',
#       'primary': True,
#       'shortName': 'Sushi'}],
#     'hasPerk': False,
#     'id': '4fbbb3ace4b01e39077b4d55',
#     'location': {'address': '220 Yonge St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'in Toronto Eaton Centre Urban Eatery',
#      'distance': 388,
#      'formattedAddress': ['220 Yonge St. (in Toronto Eaton Centre Urban Eatery)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65596504293232,
#        'lng': -79.38054070644233}],
#      'lat': 43.65596504293232,
#      'lng': -79.38054070644233,
#      'state': 'ON'},
#     'name': 'Akashiro Japanese Restaurant & Bar',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'primary': True,
#       'shortName': 'Asian'}],
#     'hasPerk': False,
#     'id': '4de827e4d4c0faa56428a51a',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 433,
#      'formattedAddress': ['Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.651587,
#        'lng': -79.379232}],
#      'lat': 43.651587,
#      'lng': -79.379232,
#      'state': 'ON'},
#     'name': 'Yulla Asian Fusion Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'primary': True,
#       'shortName': 'Italian'}],
#     'hasPerk': False,
#     'id': '4afcc52df964a520b82522e3',
#     'location': {'address': '37 Elm St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Bay St.',
#      'distance': 446,
#      'formattedAddress': ['37 Elm St. (at Bay St.)',
#       'Toronto ON M5G 1H1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.657489310288014,
#        'lng': -79.38360495100461}],
#      'lat': 43.657489310288014,
#      'lng': -79.38360495100461,
#      'postalCode': 'M5G 1H1',
#      'state': 'ON'},
#     'name': 'Donatello Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d144941735',
#       'name': 'Caribbean Restaurant',
#       'pluralName': 'Caribbean Restaurants',
#       'primary': True,
#       'shortName': 'Caribbean'}],
#     'hasPerk': False,
#     'id': '4ba2ab4af964a520650e38e3',
#     'location': {'cc': 'CA',
#      'city': 'Bolton',
#      'country': 'Canada',
#      'distance': 506,
#      'formattedAddress': ['Bolton ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64955,
#        'lng': -79.38078}],
#      'lat': 43.64955,
#      'lng': -79.38078,
#      'state': 'ON'},
#     'name': 'Vineyard Jamaican Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '5a8b24b2018cbb6c4ca70dae',
#     'location': {'address': 'Yonge And Queen',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Queen St',
#      'distance': 341,
#      'formattedAddress': ['Yonge And Queen (Queen St)',
#       'Toronto ON M5G 2H6',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65341542752959,
#        'lng': -79.37969842137554}],
#      'lat': 43.65341542752959,
#      'lng': -79.37969842137554,
#      'postalCode': 'M5G 2H6',
#      'state': 'ON'},
#     'name': 'Hendricks Restaurant & Bar',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d157941735',
#       'name': 'New American Restaurant',
#       'pluralName': 'New American Restaurants',
#       'primary': True,
#       'shortName': 'New American'}],
#     'hasPerk': False,
#     'id': '50c77c28e4b09076e33b9fa2',
#     'location': {'address': '30 Carlton St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'College and Yonge',
#      'distance': 926,
#      'formattedAddress': ['30 Carlton St (College and Yonge)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.66153280071713,
#        'lng': -79.38101182087826}],
#      'lat': 43.66153280071713,
#      'lng': -79.38101182087826,
#      'state': 'ON'},
#     'name': 'Carlton Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d147941735',
#       'name': 'Diner',
#       'pluralName': 'Diners',
#       'primary': True,
#       'shortName': 'Diner'}],
#     'hasPerk': False,
#     'id': '4ad7929cf964a520500c21e3',
#     'location': {'address': '249 Victoria Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'btwn Dundas St E and Shuter St',
#      'distance': 450,
#      'formattedAddress': ['249 Victoria Street (btwn Dundas St E and Shuter St)',
#       'Toronto ON M5B 1T8',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65564091455335,
#        'lng': -79.37919882575557}],
#      'lat': 43.65564091455335,
#      'lng': -79.37919882575557,
#      'postalCode': 'M5B 1T8',
#      'state': 'ON'},
#     'name': 'The Senator Restaurant',
#     'referralId': 'v-1597056531',
#     'venuePage': {'id': '55585058'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dimsum_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1f5931735',
#       'name': 'Dim Sum Restaurant',
#       'pluralName': 'Dim Sum Restaurants',
#       'primary': True,
#       'shortName': 'Dim Sum'}],
#     'hasPerk': False,
#     'id': '4b2a674ef964a52074a824e3',
#     'location': {'address': '150 Dundas St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Elizabeth',
#      'distance': 240,
#      'formattedAddress': ['150 Dundas St W (at Elizabeth)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65538444237565,
#        'lng': -79.3853618106867}],
#      'lat': 43.65538444237565,
#      'lng': -79.3853618106867,
#      'state': 'ON'},
#     'name': 'New Treasure Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4b82c671f964a52016e430e3',
#     'location': {'address': '250 Dundas St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 479,
#      'formattedAddress': ['250 Dundas St W', 'Toronto ON M5T 2Z5', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654588,
#        'lng': -79.389692}],
#      'lat': 43.654588,
#      'lng': -79.389692,
#      'postalCode': 'M5T 2Z5',
#      'state': 'ON'},
#     'name': 'Anoush Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '52a7ae41498eed3af4d0a3fa',
#     'location': {'address': '126 Elizabeth St.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Dundas St.',
#      'distance': 229,
#      'formattedAddress': ['126 Elizabeth St. (Dundas St.)',
#       'Toronto ON M5G 1P5',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655281263429195,
#        'lng': -79.3853365267765}],
#      'lat': 43.655281263429195,
#      'lng': -79.3853365267765,
#      'postalCode': 'M5G 1P5',
#      'state': 'ON'},
#     'name': 'Yueh Tung Chinese Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4b2027b5f964a520f82d24e3',
#     'location': {'address': '195 Dundas St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at University Ave',
#      'distance': 300,
#      'formattedAddress': ['195 Dundas St W (at University Ave)',
#       'Toronto ON M5G 1C7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65492521335936,
#        'lng': -79.38708916106386}],
#      'lat': 43.65492521335936,
#      'lng': -79.38708916106386,
#      'postalCode': 'M5G 1C7',
#      'state': 'ON'},
#     'name': 'Hong Shing Chinese Restaurant',
#     'referralId': 'v-1597056531',
#     'venuePage': {'id': '60327598'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d10f941735',
#       'name': 'Indian Restaurant',
#       'pluralName': 'Indian Restaurants',
#       'primary': True,
#       'shortName': 'Indian'}],
#     'hasPerk': False,
#     'id': '5165c333e4b07a7ad88d8a69',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 553,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65814977325445,
#        'lng': -79.38156263736568}],
#      'lat': 43.65814977325445,
#      'lng': -79.38156263736568},
#     'name': "Joe's Indian Restaurant",
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4c69740b8d22c9284d42b745',
#     'location': {'address': '56 Centre Ave.',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 303,
#      'formattedAddress': ['56 Centre Ave.', 'Toronto ON M5G 1R5', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65483285234745,
#        'lng': -79.38720597193928}],
#      'lat': 43.65483285234745,
#      'lng': -79.38720597193928,
#      'postalCode': 'M5G 1R5',
#      'state': 'ON'},
#     'name': 'Wah Too Seafood Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/japanese_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d111941735',
#       'name': 'Japanese Restaurant',
#       'pluralName': 'Japanese Restaurants',
#       'primary': True,
#       'shortName': 'Japanese'}],
#     'hasPerk': False,
#     'id': '4c12b8ba82a3c9b6083ffaf8',
#     'location': {'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 571,
#      'formattedAddress': ['Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.658555,
#        'lng': -79.384992}],
#      'lat': 43.658555,
#      'lng': -79.384992,
#      'state': 'ON'},
#     'name': 'Mt. Fuji Japanese Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '52e81612bcbc57f1066b79f9',
#       'name': 'Modern European Restaurant',
#       'pluralName': 'Modern European Restaurants',
#       'primary': True,
#       'shortName': 'Modern European'}],
#     'hasPerk': False,
#     'id': '539c6f13498e06f4cc765165',
#     'location': {'address': '43 Elm St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Bay',
#      'distance': 436,
#      'formattedAddress': ['43 Elm St (Bay)', 'Toronto ON M5G 1H1', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65739749535259,
#        'lng': -79.38376054171513}],
#      'lat': 43.65739749535259,
#      'lng': -79.38376054171513,
#      'postalCode': 'M5G 1H1',
#      'state': 'ON'},
#     'name': 'The Elm Tree Restaurant',
#     'referralId': 'v-1597056531',
#     'venuePage': {'id': '88534436'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'primary': True,
#       'shortName': 'Asian'}],
#     'hasPerk': False,
#     'id': '51e2cd6f498e10d88582ae4f',
#     'location': {'address': '64 Queen Street East',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Church Street',
#      'distance': 681,
#      'formattedAddress': ['64 Queen Street East (Church Street)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653364490464604,
#        'lng': -79.37547565899231}],
#      'lat': 43.653364490464604,
#      'lng': -79.37547565899231,
#      'state': 'ON'},
#     'name': 'T.C.J. Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d121941735',
#       'name': 'Lounge',
#       'pluralName': 'Lounges',
#       'primary': True,
#       'shortName': 'Lounge'}],
#     'hasPerk': False,
#     'id': '4fdfc6c1e4b03326d77bd7c8',
#     'location': {'address': '225 Jarvis St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'btwn Dundas St. & Shuter St.',
#      'distance': 841,
#      'formattedAddress': ['225 Jarvis St (btwn Dundas St. & Shuter St.)',
#       'Toronto ON M5B 2C1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65627304573888,
#        'lng': -79.37422062269164}],
#      'lat': 43.65627304573888,
#      'lng': -79.37422062269164,
#      'postalCode': 'M5B 2C1',
#      'state': 'ON'},
#     'name': 'Citrus Restaurant & Lounge @ The Grand Hotel',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '5c636fa1492814002c0cb117',
#     'location': {'address': '100 Yonge St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Yonge and King',
#      'distance': 607,
#      'formattedAddress': ['100 Yonge St (Yonge and King)',
#       'Toronto ON M5C 2W1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64982,
#        'lng': -79.37835}],
#      'lat': 43.64982,
#      'lng': -79.37835,
#      'neighborhood': 'Financial District',
#      'postalCode': 'M5C 2W1',
#      'state': 'ON'},
#     'name': 'Cru Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '5dfaabffbdacac0008c8a53a',
#     'location': {'address': '5 Baldwin St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 741,
#      'formattedAddress': ['5 Baldwin St', 'Toronto ON M5T 1L1', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656013,
#        'lng': -79.392451}],
#      'lat': 43.656013,
#      'lng': -79.392451,
#      'postalCode': 'M5T 1L1',
#      'state': 'ON'},
#     'name': 'The Winding Road Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4dff2649d22d48be8127cd1c',
#     'location': {'address': '81 Church Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 789,
#      'formattedAddress': ['81 Church Street', 'Toronto ON', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65182,
#        'lng': -79.37441}],
#      'lat': 43.65182,
#      'lng': -79.37441,
#      'state': 'ON'},
#     'name': "L'Apero Restaurant",
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '4b589c8ff964a520396128e3',
#     'location': {'address': '1 Baldwin Street',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at McCaul',
#      'distance': 748,
#      'formattedAddress': ['1 Baldwin Street (at McCaul)',
#       'Toronto ON',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.656277,
#        'lng': -79.392393}],
#      'lat': 43.656277,
#      'lng': -79.392393,
#      'state': 'ON'},
#     'name': "Zhu's Restaurant",
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4ad4c060f964a52070f720e3',
#     'location': {'address': '33 Elm St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'at Bay St',
#      'distance': 451,
#      'formattedAddress': ['33 Elm St (at Bay St)',
#       'Toronto ON M5G 1H1',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65751886446546,
#        'lng': -79.38346181502347}],
#      'lat': 43.65751886446546,
#      'lng': -79.38346181502347,
#      'postalCode': 'M5G 1H1',
#      'state': 'ON'},
#     'name': 'Adega Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '51e1cf9a498e3c12c7f3ca22',
#     'location': {'cc': 'CA',
#      'country': 'Canada',
#      'distance': 789,
#      'formattedAddress': ['Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655208685959636,
#        'lng': -79.3934440137687}],
#      'lat': 43.655208685959636,
#      'lng': -79.3934440137687},
#     'name': 'spring garden Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mongolian_',
#        'suffix': '.png'},
#       'id': '4eb1d5724b900d56c88a45fe',
#       'name': 'Mongolian Restaurant',
#       'pluralName': 'Mongolian Restaurants',
#       'primary': True,
#       'shortName': 'Mongolian'}],
#     'hasPerk': False,
#     'id': '525c07e211d2a64185b0f95a',
#     'location': {'address': '18 yorkville avenue',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 809,
#      'formattedAddress': ['18 yorkville avenue',
#       'Toronto ON M4W 1L4',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.648932390189465,
#        'lng': -79.37609195709229}],
#      'lat': 43.648932390189465,
#      'lng': -79.37609195709229,
#      'postalCode': 'M4W 1L4',
#      'state': 'ON'},
#     'name': 'Trial Restaurant and Bar',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '52af3b773cf9994f4e043c03',
#       'name': 'Szechuan Restaurant',
#       'pluralName': 'Szechuan Restaurants',
#       'primary': True,
#       'shortName': 'Szechuan'}],
#     'hasPerk': False,
#     'id': '5c5b8685c5b11c00398a0e6a',
#     'location': {'address': '45 Baldwin St',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 834,
#      'formattedAddress': ['45 Baldwin St', 'Toronto ON M5T 1L1', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655934,
#        'lng': -79.393731}],
#      'lat': 43.655934,
#      'lng': -79.393731,
#      'postalCode': 'M5T 1L1',
#      'state': 'ON'},
#     'name': 'Toronto Big Bowl Restaurant',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d1c4941735',
#       'name': 'Restaurant',
#       'pluralName': 'Restaurants',
#       'primary': True,
#       'shortName': 'Restaurant'}],
#     'hasPerk': False,
#     'id': '4af618daf964a520220122e3',
#     'location': {'address': '111c Queen St East',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Church',
#      'distance': 764,
#      'formattedAddress': ['111c Queen St East (Church)',
#       'Toronto ON M5C 1S2',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65334645635036,
#        'lng': -79.3744449051126}],
#      'lat': 43.65334645635036,
#      'lng': -79.3744449051126,
#      'postalCode': 'M5C 1S2',
#      'state': 'ON'},
#     'name': 'GEORGE Restaurant',
#     'referralId': 'v-1597056531',
#     'venuePage': {'id': '208931627'}},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d142941735',
#       'name': 'Asian Restaurant',
#       'pluralName': 'Asian Restaurants',
#       'primary': True,
#       'shortName': 'Asian'}],
#     'hasPerk': False,
#     'id': '4ae31ac7f964a520799021e3',
#     'location': {'address': '240 Queen Street West',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'crossStreet': 'Queen and John',
#      'distance': 660,
#      'formattedAddress': ['240 Queen Street West (Queen and John)',
#       'Toronto ON M5v1z7',
#       'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.64998452583986,
#        'lng': -79.39056268913188}],
#      'lat': 43.64998452583986,
#      'lng': -79.39056268913188,
#      'postalCode': 'M5v1z7',
#      'state': 'ON'},
#     'name': 'East Restaurant Asian Street Flair',
#     'referralId': 'v-1597056531'},
#    {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#        'suffix': '.png'},
#       'id': '4bf58dd8d48988d145941735',
#       'name': 'Chinese Restaurant',
#       'pluralName': 'Chinese Restaurants',
#       'primary': True,
#       'shortName': 'Chinese'}],
#     'hasPerk': False,
#     'id': '5aa595454aa3f802dedab924',
#     'location': {'address': '405 Dundas St W',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'country': 'Canada',
#      'distance': 872,
#      'formattedAddress': ['405 Dundas St W', 'Toronto ON M5T 1G6', 'Canada'],
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653459,
#        'lng': -79.394769}],
#      'lat': 43.653459,
#      'lng': -79.394769,
#      'postalCode': 'M5T 1G6',
#      'state': 'ON'},
#     'name': 'King Crab Seafood Restaurant',
#     'referralId': 'v-1597056531'}]}}

# %% [markdown]
# #### Get relevant part of JSON and transform it into a pandas dataframes

# %%
# assign relevant part of JSON to venues
venues_hotel      = results_hotel['response']['venues']
venues_restaurant = results_restaurant['response']['venues']

# tranform venues into a dataframe and merging both data
df_hotel      = json_normalize(venues_hotel)
df_restaurant = json_normalize(venues_restaurant)

df = pd.concat([df_hotel, df_restaurant])

print("There are {} restaurants and hotels at Toronto".format(df.shape[0]))
# Out:
# There are 100 restaurants and hotels at Toronto

# %% [markdown]
# #### Define information of interest and filter dataframe

# %%
# keep only columns that include venue name, and anything that is associated with location
flt_columns = ['name', 'categories'] + [col for col in df.columns if col.startswith('location.')] + ['id']
df_flt      = df.loc[:, flt_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    
# filter the category for each row
df_flt['categories'] = df_flt.apply(get_category_type, axis=1)
  
# clean column names by keeping only last term
df_flt.columns = [column.split('.')[-1] for column in df_flt.columns]

#dataframe_filtered
hotels_df=df_flt[['name','categories','distance','lat','lng','id']]
hotels_df.head()
# Out:
#                               name categories  distance        lat        lng  \
# 0    Sheraton Centre Toronto Hotel      Hotel       324  43.650594 -79.384530
# 1  One King West Hotel & Residence      Hotel       686  43.649139 -79.377876
# 2                    Chelsea Hotel      Hotel       562  43.658498 -79.383097
# 3       The Omni King Edward Hotel      Hotel       797  43.649191 -79.376006
# 4             Pantages Hotel & Spa      Hotel       410  43.654498 -79.379035
#
#                          id
# 0  4ab2d511f964a5209b6c20e3
# 1  4af96fbbf964a520c01122e3
# 2  51d212c3498ebf27dc469bc9
# 3  4adf7d0bf964a520127b21e3
# 4  4ae61cf6f964a520caa421e3

# %% [markdown]
# #### Location of Hotels

# %%
hotels_map = folium.Map(location=[latitude, longitude], zoom_start=11) # generate map centred around the Toronto

# add a red circle marker to represent the core location of Toronto
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='#3388ff',
    popup='Toronto',
    fill_opacity = 0.7
).add_to(hotels_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(hotels_df.lat, hotels_df.lng, hotels_df.name):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='Blue',
        fill_opacity=0.7
    ).add_to(hotels_map)

# display map
hotels_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
